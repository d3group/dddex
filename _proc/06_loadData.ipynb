# %% [raw]
# ---
# description: The functions in this notebook load datasets that can be used to test
#   the presented procedures of this package.
# output-file: loaddata.html
# title: Load Datasets
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Yaz

# %%
#| echo: false
#| output: asis
show_doc(loadDataYaz)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/loadData.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### loadDataYaz
#
# >      loadDataYaz (returnXY=True)

# %%
#| echo: false
#| output: asis
show_doc(loadDataYaz_multivariate)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/loadData.py#L42){target="_blank" style="float:right; font-size:smaller"}
#
# ### loadDataYaz_multivariate
#
# >      loadDataYaz_multivariate (returnXY=True)

# %% [markdown]
# ## Bakery

# %%
#| echo: false
#| output: asis
show_doc(loadDataBakery)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/loadData.py#L65){target="_blank" style="float:right; font-size:smaller"}
#
# ### loadDataBakery
#
# >      loadDataBakery (returnXY=True)
