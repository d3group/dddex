# %% [raw]
# ---
# description: Fill in a module description here
# output-file: basepredictor.html
# title: Base Class
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Packages

# %% [markdown]
# ## Base Class - Weights-Based Predictor

# %%
#|output: asis
#| echo: false
show_doc(BasePredictor)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/basePredictor.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### BasePredictor
#
# >      BasePredictor ()
#
# Base class that implements the 'prediction'-method for approaches based
# on a reweighting of the empirical distribution.

# %%
#|output: asis
#| echo: false
show_doc(BasePredictor.predictQ)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/basePredictor.py#L38){target="_blank" style="float:right; font-size:smaller"}
#
# ### BasePredictor.predictQ
#
# >      BasePredictor.predictQ (X, probs=[0.1, 0.5, 0.9], outputAsDf=False,
# >                              scalingList=None)

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# ### Restructure Weights Data List

# %%
#|output: asis
#| echo: false
show_doc(restructureWeightsDataList)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/basePredictor.py#L73){target="_blank" style="float:right; font-size:smaller"}
#
# ### restructureWeightsDataList
#
# >      restructureWeightsDataList (weightsDataList,
# >                                  outputType='onlyPositiveWeights', y=None,
# >                                  scalingList=None, equalWeights=False)

# %% [markdown]
# #### Summarize Weights Data

# %%
#|output: asis
#| echo: false
show_doc(summarizeWeightsData)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/basePredictor.py#L159){target="_blank" style="float:right; font-size:smaller"}
#
# ### summarizeWeightsData
#
# >      summarizeWeightsData (weightsPos, yWeightPos, equalWeights=False)
