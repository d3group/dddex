# %% [raw]
# ---
# description: Fill in a module description here
# output-file: utils.html
# title: Helper Functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Packages

# %% [markdown]
# ## Restructure Weights Data List

# %%
#| echo: false
#| output: asis
show_doc(restructureWeightsDataList)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/utils.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### restructureWeightsDataList
#
# >      restructureWeightsDataList (weightsDataList,
# >                                  outputType='onlyPositiveWeights', y=None,
# >                                  scalingList=None, equalWeights=False)

# %% [markdown]
# ### Summarize Weights Data

# %%
#| echo: false
#| output: asis
show_doc(summarizeWeightsData)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/utils.py#L133){target="_blank" style="float:right; font-size:smaller"}
#
# ### summarizeWeightsData
#
# >      summarizeWeightsData (weightsPos, yWeightPos, equalWeights=False)

# %% [markdown]
# ## Restructure Weights Data List - Multivariate

# %%
#| echo: false
#| output: asis
show_doc(restructureWeightsDataList_multivariate)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/utils.py#L168){target="_blank" style="float:right; font-size:smaller"}
#
# ### restructureWeightsDataList_multivariate
#
# >      restructureWeightsDataList_multivariate (weightsDataList,
# >                                               outputType='onlyPositiveWeights'
# >                                               , y=None, scalingList=None,
# >                                               equalWeights=False)

# %% [markdown]
# ### Summarize Weights Data - Multivariate

# %%
#| echo: false
#| output: asis
show_doc(summarizeWeightsData_multivariate)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/utils.py#L220){target="_blank" style="float:right; font-size:smaller"}
#
# ### summarizeWeightsData_multivariate
#
# >      summarizeWeightsData_multivariate (weightsPos, yWeightPos,
# >                                         equalWeights=False)

# %% [markdown]
# ## Generate Output

# %%
#| echo: false
#| output: asis
show_doc(generateFinalOutput)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/utils.py#L254){target="_blank" style="float:right; font-size:smaller"}
#
# ### generateFinalOutput
#
# >      generateFinalOutput (dataOriginal, dataDecisions,
# >                           targetVariable='demand', mergeOn=None,
# >                           variablesToAdd=None, scaleBy=None,
# >                           includeTraining=False, sortBy=None,
# >                           longFormat=False, **kwargs)
