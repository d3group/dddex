# %% [raw]
# ---
# description: Fill in a module description here
# output-file: utils.html
# title: Helper Functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Packages

# %% [markdown]
# ## Grouped Time Series Split

# %%
#|output: asis
#| echo: false
show_doc(groupedTimeSeriesSplit)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/utils.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### groupedTimeSeriesSplit
#
# >      groupedTimeSeriesSplit (data, kFolds, testLength, groupFeature,
# >                              timeFeature)

# %% [markdown]
# ## Generate Output

# %%
#|output: asis
#| echo: false
show_doc(generateFinalOutput)
# Out:
# ---
#
# [source](https://github.com/kaiguender/dddex/blob/main/dddex/utils.py#L73){target="_blank" style="float:right; font-size:smaller"}
#
# ### generateFinalOutput
#
# >      generateFinalOutput (dataOriginal, dataDecisions,
# >                           targetVariable='demand', mergeOn=None,
# >                           variablesToAdd=None, scaleBy=None,
# >                           includeTraining=False, sortBy=None,
# >                           longFormat=False, **kwargs)
